# %%
import pandas as pd
import seaborn as sns
import datetime
from pandas.plotting import register_matplotlib_converters
import matplotlib.pyplot as plt
register_matplotlib_converters()
sns.set(style="whitegrid")

# %%
def save_to_pdf(filename, ax):
    fig = ax.get_figure()
    fig.savefig(filename, bbox_inches='tight')

# %%
df = pd.read_csv('/mnt/data/datasets/newspapers/guardian/c_articles.csv')

# %%
df.iloc[0]['article_url']
# Out:
# 'https://www.theguardian.com/commentisfree/2012/feb/09/women-at-work-equality'

# %%
months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec', ]
dates = df['article_url'].apply(lambda url: pd.Series([x for x in url.split('/') if x.isdigit() or x in months]))

# %%
df = df.join(dates, how='left')

# %%
df = df.rename(index=str, columns={0: "year", 1: "month", 2: 'day'})

# %%
months_dict = {'jan' : 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6, 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12}

# %%
df
# Out:
#         article_id                                        article_url  year  \
# 0                1  https://www.theguardian.com/commentisfree/2012...  2012
# 1                3  https://www.theguardian.com/business/2012/feb/...  2012
# 2                4  https://www.theguardian.com/travel/2012/feb/08...  2012
# 3                5  https://www.theguardian.com/lifeandstyle/2012/...  2012
# 4                6  https://www.theguardian.com/fashion/2012/feb/0...  2012
# ...            ...                                                ...   ...
# 626390      626392  https://www.theguardian.com/news/blog/2006/may...  2006
# 626391      626393  https://www.theguardian.com/news/blog/2006/may...  2006
# 626392      626394  https://www.theguardian.com/news/blog/2006/may...  2006
# 626393      626395  https://www.theguardian.com/news/blog/2006/apr...  2006
# 626394      626396  https://www.theguardian.com/news/blog/2006/apr...  2006
#
#        month day    3
# 0        feb  09  NaN
# 1        feb  09  NaN
# 2        feb  08  NaN
# 3        feb  07  NaN
# 4        feb  06  NaN
# ...      ...  ..  ...
# 626390   may  17  NaN
# 626391   may  15  NaN
# 626392   may  09  NaN
# 626393   apr  20  NaN
# 626394   apr  14  NaN
#
# [626395 rows x 6 columns]

# %%
dates
# Out:
#            0    1   2    3
# 0       2012  feb  09  NaN
# 1       2012  feb  09  NaN
# 2       2012  feb  08  NaN
# 3       2012  feb  07  NaN
# 4       2012  feb  06  NaN
# ...      ...  ...  ..  ...
# 626390  2006  may  17  NaN
# 626391  2006  may  15  NaN
# 626392  2006  may  09  NaN
# 626393  2006  apr  20  NaN
# 626394  2006  apr  14  NaN
#
# [626395 rows x 4 columns]

# %%
df = df[['article_id', 'article_url', 'year', 'month', 'day']]

# %%
df.describe()
# Out:
#           article_id
# count  626395.000000
# mean   313198.999998
# std    180824.805275
# min         1.000000
# 25%    156600.500000
# 50%    313199.000000
# 75%    469797.500000
# max    626396.000000

# %%
df = df.dropna()

# %%
timestamps = []

for index, row in df.iterrows():
    year = int(row['year'])
    if year == 200:
        year = 2008
    day = int(row['day'])
    month = months_dict[row['month']]
    timestamps.append(pd.Timestamp(datetime.datetime(year, month , day)))

# %%
df['timestamps'] = timestamps

# %%
df['year'] = df['year'].astype('int64')

# %%
df = df[df['year'] <= 2017]
df = df[df['year'] >= 2005]

# %%
count_df = df.groupby('timestamps')['article_id'].count()
count_df = count_df.reset_index()

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(x="timestamps", y="article_id", data=count_df)
ax.set(xlabel='Publication Date', ylabel='Number of Articles')
save_to_pdf('./plots/daily_number_of_articles_per_day.pdf', ax)

# %%
count_df.reset_index().head(1)
# Out:
#    index timestamps  article_id
# 0      0 2005-08-14           1

# %%
count_year_df = df.groupby('year')['article_id'].count().reset_index()

# %%
plt.figure(figsize=(15,6))
ax = sns.lineplot(x="year", y="article_id", data=count_year_df)
ax.set(xlabel='Publication Date', ylabel='Number of Articles')
save_to_pdf('./plots/daily_number_of_articles_per_day.pdf', ax)

# %%
df
# Out:
#         article_id                                        article_url  year  \
# 0                1  https://www.theguardian.com/commentisfree/2012...  2012
# 1                3  https://www.theguardian.com/business/2012/feb/...  2012
# 2                4  https://www.theguardian.com/travel/2012/feb/08...  2012
# 3                5  https://www.theguardian.com/lifeandstyle/2012/...  2012
# 4                6  https://www.theguardian.com/fashion/2012/feb/0...  2012
# ...            ...                                                ...   ...
# 626390      626392  https://www.theguardian.com/news/blog/2006/may...  2006
# 626391      626393  https://www.theguardian.com/news/blog/2006/may...  2006
# 626392      626394  https://www.theguardian.com/news/blog/2006/may...  2006
# 626393      626395  https://www.theguardian.com/news/blog/2006/apr...  2006
# 626394      626396  https://www.theguardian.com/news/blog/2006/apr...  2006
#
#        month day timestamps
# 0        feb  09 2012-02-09
# 1        feb  09 2012-02-09
# 2        feb  08 2012-02-08
# 3        feb  07 2012-02-07
# 4        feb  06 2012-02-06
# ...      ...  ..        ...
# 626390   may  17 2006-05-17
# 626391   may  15 2006-05-15
# 626392   may  09 2006-05-09
# 626393   apr  20 2006-04-20
# 626394   apr  14 2006-04-14
#
# [624642 rows x 6 columns]

# %%
df['month_year'] = df['timestamps'].dt.to_period('M')

# %%
df
# Out:
#         article_id                                        article_url  year  \
# 0                1  https://www.theguardian.com/commentisfree/2012...  2012
# 1                3  https://www.theguardian.com/business/2012/feb/...  2012
# 2                4  https://www.theguardian.com/travel/2012/feb/08...  2012
# 3                5  https://www.theguardian.com/lifeandstyle/2012/...  2012
# 4                6  https://www.theguardian.com/fashion/2012/feb/0...  2012
# ...            ...                                                ...   ...
# 626390      626392  https://www.theguardian.com/news/blog/2006/may...  2006
# 626391      626393  https://www.theguardian.com/news/blog/2006/may...  2006
# 626392      626394  https://www.theguardian.com/news/blog/2006/may...  2006
# 626393      626395  https://www.theguardian.com/news/blog/2006/apr...  2006
# 626394      626396  https://www.theguardian.com/news/blog/2006/apr...  2006
#
#        month day timestamps month_year
# 0        feb  09 2012-02-09    2012-02
# 1        feb  09 2012-02-09    2012-02
# 2        feb  08 2012-02-08    2012-02
# 3        feb  07 2012-02-07    2012-02
# 4        feb  06 2012-02-06    2012-02
# ...      ...  ..        ...        ...
# 626390   may  17 2006-05-17    2006-05
# 626391   may  15 2006-05-15    2006-05
# 626392   may  09 2006-05-09    2006-05
# 626393   apr  20 2006-04-20    2006-04
# 626394   apr  14 2006-04-14    2006-04
#
# [624642 rows x 7 columns]

# %%
count_year_month_df = df.groupby('month_year')['article_id'].count().reset_index()

# %%
count_year_month_df
# Out:
# month_year    period[M]
# article_id        int64
# dtype: object

# %%
sns.set()
sns.set_context('paper', font_scale=1.8)
test = df.groupby([pd.Grouper(key='timestamps', freq='M')])['article_id'].count().iloc[:-2]
plt.figure(figsize=(15,6))
ax = test.plot()
ax.set_xlabel("Time")
ax.set_ylabel("Number of Articles")
save_to_pdf('./plots/guardian_number_of_articles.pdf', ax)
